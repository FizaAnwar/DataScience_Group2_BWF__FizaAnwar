# %% [markdown]
# 🔴 Task 19 ->Statistical plotting with Seaborn (regression plots, distribution plots)
#
# Linear Regression Plot (sns.regplot)
#
# Multiple Linear Regression Plot (sns.lmplot)
#
# Residual Plot (sns.residplot)
#
#
# Histogram (sns.histplot)
#
# Kernel Density Estimate (KDE) Plot (sns.kdeplot)
#
# Distribution Plot (sns.distplot)
#
# Box Plot (sns.boxplot)
#
# Violin Plot (sns.violinplot)
#
# Pair Plot (sns.pairplot)
#
#
# Heatmap (sns.heatmap)
#
# Joint Plot (sns.jointplot)
#
# Facet Grid (sns.FacetGrid)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Example dataset
df = sns.load_dataset("penguins")
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
df['bill_length_mm'].fillna(df['bill_length_mm'].mean(), inplace=True)
df['bill_depth_mm'].fillna(df['bill_depth_mm'].mean(), inplace=True)
df['flipper_length_mm'].fillna(df['flipper_length_mm'].mean(), inplace=True)
df['body_mass_g'].fillna(df['body_mass_g'].mean(), inplace=True)
categorical_columns = ['sex']
for column in categorical_columns:
    df[column].fillna('Male', inplace=True)
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen        39.10000       18.70000         181.000000
# 1  Adelie  Torgersen        39.50000       17.40000         186.000000
# 2  Adelie  Torgersen        40.30000       18.00000         195.000000
# 3  Adelie  Torgersen        43.92193       17.15117         200.915205
# 4  Adelie  Torgersen        36.70000       19.30000         193.000000
#
#    body_mass_g     sex
# 0  3750.000000    Male
# 1  3800.000000  Female
# 2  3250.000000  Female
# 3  4201.754386    Male
# 4  3450.000000  Female

# %%
# Setting the style
sns.set_style('whitegrid')

# Linear Regression Plot
sns.regplot(data=df, x='bill_length_mm', y='bill_depth_mm')
plt.title('Linear Regression Plot of bill_length_mm vs bill_depth_mm')
plt.xlabel('bill_length_mm')
plt.ylabel('bill_depth_mm')
plt.show()

# %%
# Multiple Linear Regression Plot
sns.lmplot(data=df, x='bill_length_mm', y='flipper_length_mm', hue='sex')
plt.title('Multiple Linear Regression Plot of bill_length_mm vs flipper_length_mm by Sex')
plt.xlabel('Bill_Length_mm')
plt.ylabel('Flipper_Length_mm')
plt.show()

# %%
# Residual Plot
sns.residplot(data=df, x='bill_length_mm', y='body_mass_g')
plt.title('Residual Plot of Bill_length_mm vs body_mass_g')
plt.xlabel('Bill_length_mm')
plt.ylabel('Body_mass_g')
plt.show()

# %%
# Histogram
sns.histplot(data=df, x='species', bins=30, kde=True)
plt.title('Histogram of species')
plt.xlabel('Species')
plt.ylabel('Frequency')
plt.show()

# %%
# Histogram
sns.histplot(data=df, x='island', bins=30, kde=True)
plt.title('Histogram of island')
plt.xlabel('island')
plt.ylabel('Frequency')
plt.show()

# %%
# KDE Plot
sns.kdeplot(data=df, x='body_mass_g', shade=True)
plt.title('KDE Plot of Body_mass_g')
plt.xlabel('body_mass_g	')
plt.ylabel('Density')
plt.show()
# Out:
# <ipython-input-8-2f262c297668>:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=df, x='body_mass_g', shade=True)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Distribution Plot
sns.histplot(data=df, x='bill_depth_mm', kde=True)
plt.title('Distribution Plot of Bill_depth_mm	')
plt.xlabel('Bill_depth_mm	')
plt.ylabel('Density')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Box Plot
sns.boxplot(data=df, x='species', y='bill_length_mm')
plt.title('Box Plot of bill_length_mm	by Species')
plt.xlabel('Species')
plt.ylabel('Bill_length_mm')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Violin Plot
sns.violinplot(data=df, x='sex', y='bill_depth_mm', hue='sex', split=True)
plt.title('Violin Plot of Bill_depth_mm by Sex')
plt.xlabel('Sex')
plt.ylabel('Bill_depth_mm')
plt.show()

# %%
# Pair Plot
sns.pairplot(df, hue='sex')
plt.suptitle('Pair Plot of Species Dataset', y=1.02)
plt.show()

# %%
for column in df.columns:
    # Attempt to convert the column to numeric, coerce errors to NaN
    df['species'] = pd.to_numeric(df['species'], errors='coerce')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            0 non-null      float64
#  1   island             344 non-null    object
#  2   bill_length_mm     344 non-null    float64
#  3   bill_depth_mm      344 non-null    float64
#  4   flipper_length_mm  344 non-null    float64
#  5   body_mass_g        344 non-null    float64
#  6   sex                344 non-null    object
# dtypes: float64(5), object(2)
# memory usage: 18.9+ KB

# %%
# Select only numeric columns
numeric_df = df.select_dtypes(include=[float, int])

# Compute the correlation matrix
corr = numeric_df.corr()


# Heatmap
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Heatmap of species dataset Correlation Matrix')
plt.show()

# %%
# Joint Plot
sns.jointplot(data=df, x='bill_length_mm', y='island', kind='reg')
plt.suptitle('Joint Plot of bill_length_mm vs island', y=1.02)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-997f07f66cb3> in <cell line: 2>()
#       1 # Joint Plot
# ----> 2 sns.jointplot(data=df, x='bill_length_mm', y='island', kind='reg')
#       3 plt.suptitle('Joint Plot of bill_length_mm vs island', y=1.02)
#       4 plt.show()
#
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py in jointplot(data, x, y, hue, kind, height, ratio, space, dropna, xlim, ylim, color, palette, hue_order, hue_norm, marginal_ticks, joint_kws, marginal_kws, **kwargs)
#    2324
#    2325         joint_kws.setdefault("color", color)
# -> 2326         grid.plot_joint(regplot, **joint_kws)
#    2327
#    2328     elif kind.startswith("resid"):
#
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py in plot_joint(self, func, **kwargs)
#    1830
#    1831         if str(func.__module__).startswith("seaborn"):
# ...

# %%
# Facet Grid
g = sns.FacetGrid(df, col='sex', row='island')
g.map(sns.scatterplot, 'bill_length_mm', 'flipper_length_mm')
g.add_legend()
plt.show()
